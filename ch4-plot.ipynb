# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
x = [0,1]
y = [2,3]
plot(x,y,color='b') #不包含端点
# plot(x,y,marker='o',color='b') #包含端点

# %%
x = [0,1]
y = [2,3]
# plot(x,y,color='b') #不包含端点
plot(x,y,marker='o',color='b') #包含端点

# %%
x = [0,2,0,-2,0]
y = [4,0,-4,0,4]
plot(0,0,marker='<',markersize=100,color='b')
plot(0,0,marker='>',markersize=100,color='r')

# %%
x = [-1,1,0,0,-1,-2]
y = [3,3,3,0,-0.5,0]
plot(x,y,marker='o',markersize=10,color='b')

# %%
x = [0,2,-2,0]
y = [4,0,0,4]
plot(x,y,markersize=10,color='b')

# %%
x = [0,2,0,-2,0]
y = [4,0,-4,0,4]
plot(x,y,markersize=10,color='b')

# %%
x = [-1,-0.6,-0.3,0.3,0.6,1,0,0,0,0,0,0,0,-1,-2]
y = [3,3,3,3,3,3,3,2.5,2,1.5,1,0.5,0,-0.5,0]
plot(x,y,'o',color='b')
